# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import linear, relu, sigmoid

import matplotlib.pyplot as plt


import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

np.set_printoptions(precision=2)
# Out:
# 2023-04-18 22:24:32.962581: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-18 22:24:33.070316: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-18 22:24:33.072124: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-18 22:24:34.432251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def my_softmax(z):  

    ez = np.exp(z)              #element-wise exponenial
    sm = ez/np.sum(ez)
    return(sm)

# %%
def load_data():
    X = np.load("X9.npy")
    y = np.load("y9.npy")
    return X, y

# %%
# load dataset
X, y = load_data()

# %%
def widgvis(fig):
    fig.canvas.toolbar_visible = False
    fig.canvas.header_visible = False
    fig.canvas.footer_visible = False

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# You do not need to modify anything in this cell

m, n = X.shape

fig, axes = plt.subplots(8,8, figsize=(5,5))
fig.tight_layout(pad=0.13,rect=[0, 0.03, 1, 0.91]) #[left, bottom, right, top]

#fig.tight_layout(pad=0.5)
widgvis(fig)
for i,ax in enumerate(axes.flat):
    # Select random indices
    random_index = np.random.randint(m)
    
    # Select rows corresponding to the random indices and
    # reshape the image
    X_random_reshaped = X[random_index].reshape((20,20)).T
    
    # Display the image
    ax.imshow(X_random_reshaped, cmap='gray')
    
    # Display the label above the image
    ax.set_title(y[random_index,0])
    ax.set_axis_off()
    fig.suptitle("Label, image", fontsize=14)

# %%
tf.random.set_seed(1234) # for consistent results
model = Sequential(
    [               
        ### START CODE HERE ### 
        
        tf.keras.Input(shape=(400,)),
        Dense(25, activation = 'relu',name ="layer1"),
        Dense(15, activation = 'relu',name ="layer2"),
        Dense(10, activation = 'linear',name ="layer3")    # < softmax activation here        
        
        
        ### END CODE HERE ### 
    ], name = "my_model" 
)
# Out:
# 2023-04-18 22:29:24.688752: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error

# %%
model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 25)                10025
#
#  layer2 (Dense)              (None, 15)                390
#
#  layer3 (Dense)              (None, 10)                160
#
# =================================================================
# Total params: 10,575
# Trainable params: 10,575
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
)

history = model.fit(
    X,y,
    epochs=40
)
# Out:
# Epoch 1/40
# 157/157 [==============================] - 2s 5ms/step - loss: 1.4444
# Epoch 2/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.5476
# Epoch 3/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3964
# Epoch 4/40
# 157/157 [==============================] - 1s 6ms/step - loss: 0.3357
# Epoch 5/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.2981
# Epoch 6/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2696
# Epoch 7/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.2479
# Epoch 8/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.2279
# Epoch 9/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.2137
# Epoch 10/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1930
# Epoch 11/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1825
# Epoch 12/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1708
# Epoch 13/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1604
# Epoch 14/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.1476
# Epoch 15/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.1369
# Epoch 16/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1300
# Epoch 17/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.1205
# Epoch 18/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.1145
# Epoch 19/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.1049
# Epoch 20/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0995
# Epoch 21/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0957
# Epoch 22/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0900
# Epoch 23/40
# 157/157 [==============================] - 1s 8ms/step - loss: 0.0844
# Epoch 24/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0774
# Epoch 25/40
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0723
# Epoch 26/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0688
# Epoch 27/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0663
# Epoch 28/40
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0600
# Epoch 29/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0563
# Epoch 30/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0551
# Epoch 31/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0477
# Epoch 32/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0450
# Epoch 33/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0445
# Epoch 34/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0394
# Epoch 35/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0356
# Epoch 36/40
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0370
# Epoch 37/40
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0330
# Epoch 38/40
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0299
# Epoch 39/40
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0280
# Epoch 40/40
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0254

# %%
def display_digit(X):
    """ display a single digit. The input is one digit (400,). """
    fig, ax = plt.subplots(1,1, figsize=(0.5,0.5))
    widgvis(fig)
    X_reshaped = X.reshape((20,20)).T
    # Display the image
    ax.imshow(X_reshaped, cmap='gray')
    plt.show()

# %%
image_of_two = X[1015]
display_digit(image_of_two)

prediction = model.predict(image_of_two.reshape(1,400))  # prediction

print(f" predicting a Two: \n{prediction}")
print(f" Largest Prediction index: {np.argmax(prediction)}")
# Out:
# 1/1 [==============================] - 0s 182ms/step
#  predicting a Two:
# [[-10.54   0.62   3.25  -0.45 -12.07  -8.5  -10.59  -0.43  -4.61  -5.68]]
#  Largest Prediction index: 2

# %%
prediction_p = tf.nn.softmax(prediction)

print(f" predicting a Two. Probability vector: \n{prediction_p}")
print(f"Total of predictions: {np.sum(prediction_p):0.3f}")
# Out:
#  predicting a Two. Probability vector:
# [[9.11e-07 6.42e-02 8.91e-01 2.20e-02 1.97e-07 6.97e-06 8.69e-07 2.24e-02
#   3.43e-04 1.18e-04]]
# Total of predictions: 1.000

# %%
yhat = np.argmax(prediction_p)

print(f"np.argmax(prediction_p): {yhat}")
# Out:
# np.argmax(prediction_p): 2

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# You do not need to modify anything in this cell

m, n = X.shape

fig, axes = plt.subplots(8,8, figsize=(5,5))
fig.tight_layout(pad=0.13,rect=[0, 0.03, 1, 0.91]) #[left, bottom, right, top]
widgvis(fig)
for i,ax in enumerate(axes.flat):
    # Select random indices
    random_index = np.random.randint(m)
    
    # Select rows corresponding to the random indices and
    # reshape the image
    X_random_reshaped = X[random_index].reshape((20,20)).T
    
    # Display the image
    ax.imshow(X_random_reshaped, cmap='gray')
    
    # Predict using the Neural Network
    prediction = model.predict(X[random_index].reshape(1,400))
    prediction_p = tf.nn.softmax(prediction)
    yhat = np.argmax(prediction_p)
    
    # Display the label above the image
    ax.set_title(f"{y[random_index,0]},{yhat}",fontsize=10)
    ax.set_axis_off()
fig.suptitle("Label, yhat", fontsize=14)
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 60ms/step
